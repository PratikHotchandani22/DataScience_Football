# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from mplsoccer import Sbopen

# instantiate a parser object
parser = Sbopen()

# %% [markdown]
# ## Extracting all LaLiga matches

# %%
df_competition = parser.competition()
df_laliga_rows = df_competition[df_competition['competition_id'] == 11]

df_laliga_matches = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_matches(row):
    competition_id = row['competition_id']
    season_id = row['season_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_match = parser.match(competition_id=competition_id, season_id=season_id)
    return df_match

# Iterate through the rows and fetch matches
for index, row in df_laliga_rows.iterrows():
    matches = fetch_matches(row)
    # Append the matches to df_championsLeague_matches
    df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/684102773.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_matches = df_laliga_matches.append(matches, ignore_index=True)

# %%
df_laliga_matches[['home_score','away_score','home_team_name','away_team_name']]
# Out:
#      home_score  away_score home_team_name away_team_name
# 0             1           2      Barcelona     Celta Vigo
# 1             2           3     Real Betis      Barcelona
# 2             0           2        Osasuna      Barcelona
# 3             2           1    Real Madrid      Barcelona
# 4             1           0      Barcelona     Levante UD
# ..          ...         ...            ...            ...
# 515           2           0      Barcelona       Albacete
# 516           2           1      Barcelona     Levante UD
# 517           1           2       Albacete      Barcelona
# 518           2           0      Barcelona         Getafe
# 519           0           1       Espanyol      Barcelona
#
# [520 rows x 4 columns]

# %% [markdown]
# Since all the matches are of Barcelona, this analysis is only for team "Barcelona"

# %% [markdown]
# ## Season-Wise Analysis without events data

# %% [markdown]
# Steps:
# 1. Group by season, find home matches for each season, find away matches for all season
# 2. Find total goals scored per season vs total goals conceded each season
# 3. Total wins per season
# 4. Total losses per season
# 5. Total draws per season
# 6. Manager's performance

# %%
team = "Barcelona"

# %% [markdown]
# ### Finding goals scored in total for home and away games and then combining the total goals scored for each season

# %%
df_home_matches = df_laliga_matches[df_laliga_matches['home_team_name'] == team]

# %%
df_away_matches = df_laliga_matches[df_laliga_matches['away_team_name'] == team]

# %%
grouped_data_home = df_home_matches.groupby("season_id")
grouped_data_away = df_away_matches.groupby("season_id")

# %%
sum_goalsScored_home = grouped_data_home['home_score'].sum()

# %%
sum_goalsScored_away = grouped_data_away['away_score'].sum()

# %%
total_goalsScored_season = sum_goalsScored_home + sum_goalsScored_away

# %%
total_goalsScored_season
# Out:
# season_id
# 1      93
# 2     104
# 4      82
# 21     93
# 22     86
# 23    111
# 24     98
# 25     80
# 26    110
# 27     98
# 37     16
# 38     43
# 39     55
# 40     61
# 41     94
# 42     72
# 90     81
# dtype: int64

# %%
scored_series = pd.Series(total_goalsScored_season,name="total scored goals")
#Convert the series to a DataFrame
df_scored_goals = scored_series.reset_index()
# Rename the columns
df_scored_goals.columns = ['season_id', 'total scored goals']
df_scored_goals
# Out:
#     season_id  total scored goals
# 0           1                  93
# 1           2                 104
# 2           4                  82
# 3          21                  93
# 4          22                  86
# 5          23                 111
# 6          24                  98
# 7          25                  80
# 8          26                 110
# 9          27                  98
# 10         37                  16
# 11         38                  43
# 12         39                  55
# 13         40                  61
# 14         41                  94
# 15         42                  72
# 16         90                  81

# %% [markdown]
# ### finding goals conceded in total for home and away games and then combining total goals conceded for each season

# %%
sum_goalsConceded_home = grouped_data_home['away_score'].sum()
sum_goalsConceded_away = grouped_data_away['home_score'].sum()
total_goalsConceded_season = sum_goalsConceded_home + sum_goalsConceded_away

# %%
total_goalsConceded_season
# Out:
# season_id
# 1     24
# 2     32
# 4     31
# 21    23
# 22    18
# 23    28
# 24    38
# 25    28
# 26    21
# 27    24
# 37     2
# 38    12
# 39    24
# 40    32
# 41    29
# 42    31
# 90    37
# dtype: int64

# %%
conceded_series = pd.Series(total_goalsConceded_season,name="total conceded goals")
#Convert the series to a DataFrame
df_conceded_goals = conceded_series.reset_index()
# Rename the columns
df_conceded_goals.columns = ['season_id', 'total conceded goals']
df_conceded_goals
# Out:
#     season_id  total conceded goals
# 0           1                    24
# 1           2                    32
# 2           4                    31
# 3          21                    23
# 4          22                    18
# 5          23                    28
# 6          24                    38
# 7          25                    28
# 8          26                    21
# 9          27                    24
# 10         37                     2
# 11         38                    12
# 12         39                    24
# 13         40                    32
# 14         41                    29
# 15         42                    31
# 16         90                    37

# %% [markdown]
# ### creating bar chart of goals scored vs goals conceded for each season

# %%
df_goals = df_laliga_matches

# %%
df_total_goals = pd.DataFrame()

# %%
df_total_goals = df_scored_goals.merge(df_conceded_goals,on='season_id', how='left')

# %%
df_total_goals
# Out:
#     season_id  total scored goals  total conceded goals
# 0           1                  93                    24
# 1           2                 104                    32
# 2           4                  82                    31
# 3          21                  93                    23
# 4          22                  86                    18
# 5          23                 111                    28
# 6          24                  98                    38
# 7          25                  80                    28
# 8          26                 110                    21
# 9          27                  98                    24
# 10         37                  16                     2
# 11         38                  43                    12
# 12         39                  55                    24
# 13         40                  61                    32
# 14         41                  94                    29
# 15         42                  72                    31
# 16         90                  81                    37

# %%
# Create a mapping dictionary of 'season_id' to 'season_name' from df_goals for the rows in df_total_goals
mapping = {row['season_id']: row['season_name'] for _, row in df_goals.iterrows() if row['season_id'] in df_total_goals['season_id'].values}

# Add the 'season_name' column to df_total_goals based on the mapping
df_total_goals['season_name'] = df_total_goals['season_id'].map(mapping)

# %%
df_total_goals
# Out:
#     season_id  total scored goals  total conceded goals season_name
# 0           1                  93                    24   2017/2018
# 1           2                 104                    32   2016/2017
# 2           4                  82                    31   2018/2019
# 3          21                  93                    23   2009/2010
# 4          22                  86                    18   2010/2011
# 5          23                 111                    28   2011/2012
# 6          24                  98                    38   2012/2013
# 7          25                  80                    28   2013/2014
# 8          26                 110                    21   2014/2015
# 9          27                  98                    24   2015/2016
# 10         37                  16                     2   2004/2005
# 11         38                  43                    12   2005/2006
# 12         39                  55                    24   2006/2007
# 13         40                  61                    32   2007/2008
# 14         41                  94                    29   2008/2009
# 15         42                  72                    31   2019/2020
# 16         90                  81                    37   2020/2021

# %%
# Create a bar plot
ax = df_total_goals.plot(x='season_name', y=['total scored goals', 'total conceded goals'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('Goals')
ax.set_title('Comparison of Total Conceded Goals and Total Scored Goals')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')


# Show the plot
plt.show()

# %% [markdown]
# ### finding total wins vs total losses for each season

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home wins each season'] = df_home_matches['home_score'] > df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_wins_per_season = df_home_matches.groupby('season_id')['home wins each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_wins_per_season, on='season_id', how='left')

# Rename the column
df_home_matches.rename(columns={'home wins each season_y': 'home wins each season'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/3531861710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_home_matches['home wins each season'] = df_home_matches['home_score'] > df_home_matches['away_score']

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away wins each season'] = df_away_matches['home_score'] < df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_wins_per_season = df_away_matches.groupby('season_id')['away wins each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_wins_per_season, on='season_id', how='left')

# Rename the column
df_away_matches.rename(columns={'away wins each season_y': 'away wins each season'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/592665768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_away_matches['away wins each season'] = df_away_matches['home_score'] < df_away_matches['away_score']

# %%
wins_home = df_home_matches[['season_id','season_name','home wins each season']]

# %%
wins_away = df_away_matches[['season_id','season_name','away wins each season']]

# %%
df_total_wins = pd.DataFrame()

# %%
wins_home
# Out:
#      season_id season_name  home wins each season
# 0           90   2020/2021                     11
# 1           90   2020/2021                     11
# 2           90   2020/2021                     11
# 3           90   2020/2021                     11
# 4           90   2020/2021                     11
# ..         ...         ...                    ...
# 257         37   2004/2005                      5
# 258         37   2004/2005                      5
# 259         37   2004/2005                      5
# 260         37   2004/2005                      5
# 261         37   2004/2005                      5
#
# [262 rows x 3 columns]

# %%
unique_pairs_home_wins = wins_home[['season_name', 'home wins each season']].drop_duplicates()
unique_pairs_home_wins.reset_index(inplace=True)

# %%
unique_pairs_away_wins = wins_away[['season_name', 'away wins each season']].drop_duplicates()
unique_pairs_away_wins.reset_index(inplace=True)

# %%
# Remove the 'index' column from the DataFrame
unique_pairs_home_wins = unique_pairs_home_wins.drop('index', axis=1)
# Out:
#    season_name  home wins each season
# 0    2020/2021                     11
# 1    2019/2020                     14
# 2    2018/2019                     14
# 3    2017/2018                     16
# 4    2016/2017                     15
# 5    2015/2016                     13
# 6    2014/2015                     16
# 7    2013/2014                     12
# 8    2012/2013                     14
# 9    2011/2012                     16
# 10   2010/2011                     14
# 11   2009/2010                     16
# 12   2008/2009                     12
# 13   2007/2008                     12
# 14   2006/2007                      9
# 15   2005/2006                      8
# 16   2004/2005                      5

# %%
unique_pairs_away_wins = unique_pairs_away_wins.drop('index', axis=1)
# Out:
#    season_name  away wins each season
# 0    2020/2021                     11
# 1    2019/2020                      8
# 2    2018/2019                     10
# 3    2017/2018                     11
# 4    2016/2017                     11
# 5    2015/2016                     12
# 6    2014/2015                     14
# 7    2013/2014                      9
# 8    2012/2013                     12
# 9    2011/2012                     11
# 10   2010/2011                     12
# 11   2009/2010                     13
# 12   2008/2009                     12
# 13   2007/2008                      4
# 14   2006/2007                      7
# 15   2005/2006                      7
# 16   2004/2005                      2

# %%
df_total_wins = unique_pairs_home_wins.merge(unique_pairs_away_wins,on='season_name', how='left')

# %%
# Create a bar plot
ax = df_total_wins.plot(x='season_name', y=['home wins each season', 'away wins each season'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('Wins')
ax.set_title('Comparison of wins on home and away')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home losses each season'] = df_home_matches['home_score'] < df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_losses_per_season = df_home_matches.groupby('season_id')['home losses each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_losses_per_season, on='season_id', how='left')

# Rename the column
df_home_matches.rename(columns={'home losses each season_y': 'home losses each season'}, inplace=True)

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away losses each season'] = df_away_matches['home_score'] > df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_losses_per_season = df_away_matches.groupby('season_id')['away losses each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_losses_per_season, on='season_id', how='left')

# Rename the column
df_away_matches.rename(columns={'away losses each season_y': 'away losses each season'}, inplace=True)

# %%
losses_home = df_home_matches[['season_id','season_name','home losses each season']]
losses_away = df_away_matches[['season_id','season_name','away losses each season']]

# %%
unique_pairs_home_losses = losses_home[['season_name', 'home losses each season']].drop_duplicates()
unique_pairs_home_losses.reset_index(inplace=True)

# %%
unique_pairs_away_losses = losses_away[['season_name', 'away losses each season']].drop_duplicates()
unique_pairs_away_losses.reset_index(inplace=True)

# %%
unique_pairs_home_losses = unique_pairs_home_losses.drop('index', axis=1)
unique_pairs_away_losses = unique_pairs_away_losses.drop('index', axis=1)

# %%
df_total_losses = unique_pairs_home_losses.merge(unique_pairs_away_losses,on='season_name', how='left')

# %%
# Create a bar plot
ax = df_total_losses.plot(x='season_name', y=['home losses each season', 'away losses each season'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('losses')
ax.set_title('Comparison of losses on home and away')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
df_total_wins['total_wins'] = df_total_wins['home wins each season'] + df_total_wins['away wins each season']

# %%
df_total_losses['total_losses'] = df_total_losses['home losses each season'] + df_total_losses['away losses each season']

# %%
df_wins_losses = df_total_wins.merge(df_total_losses,on='season_name', how='left')

# %%
# Create a bar plot
ax = df_wins_losses.plot(x='season_name', y=['total_wins', 'total_losses'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('wins and losses')
ax.set_title('Comparison of wins and losses')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# ### Adding total draws for each season too

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home draws each season'] = df_home_matches['home_score'] == df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_draws_per_season = df_home_matches.groupby('season_id')['home draws each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_draws_per_season, on='season_id', how='left')

# Rename the column
df_home_matches.rename(columns={'home draws each season_y': 'home draws each season'}, inplace=True)

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away draws each season'] = df_away_matches['home_score'] == df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_draws_per_season = df_away_matches.groupby('season_id')['away draws each season'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_draws_per_season, on='season_id', how='left')

# Rename the column
df_away_matches.rename(columns={'away draws each season_y': 'away draws each season'}, inplace=True)

# %%
draws_home = df_home_matches[['season_id','season_name','home draws each season']]
draws_away = df_away_matches[['season_id','season_name','away draws each season']]

unique_pairs_home_draws = draws_home[['season_name', 'home draws each season']].drop_duplicates()
unique_pairs_home_draws.reset_index(inplace=True)
unique_pairs_home_draws = unique_pairs_home_draws.drop('index', axis=1)

unique_pairs_away_draws = draws_away[['season_name', 'away draws each season']].drop_duplicates()
unique_pairs_away_draws.reset_index(inplace=True)
unique_pairs_away_draws = unique_pairs_away_draws.drop('index', axis=1)

# %%
df_total_draws = unique_pairs_home_draws.merge(unique_pairs_away_draws,on='season_name', how='left')

# %%
# Create a bar plot
ax = df_total_draws.plot(x='season_name', y=['home draws each season', 'away draws each season'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('losses')
ax.set_title('Comparison of draws on home and away')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
df_total_draws['total_draws'] = df_total_draws['home draws each season'] + df_total_draws['away draws each season']

# %%
df_total_draws
# Out:
#    season_name  home draws each season  away draws each season  total_draws
# 0    2020/2021                       4                       2            6
# 1    2019/2020                       2                       4            6
# 2    2018/2019                       3                       5            8
# 3    2017/2018                       3                       6            9
# 4    2016/2017                       2                       3            5
# 5    2015/2016                       1                       3            4
# 6    2014/2015                       1                       3            4
# 7    2013/2014                       2                       4            6
# 8    2012/2013                       1                       3            4
# 9    2011/2012                       1                       6            7
# 10   2010/2011                       1                       4            5
# 11   2009/2010                       0                       5            5
# 12   2008/2009                       2                       2            4
# 13   2007/2008                       1                       6            7
# 14   2006/2007                       4                       1            5
# 15   2005/2006                       1                       0            1
# 16   2004/2005                       0                       0            0

# %%
df_wins_losses_draws = df_wins_losses.merge(df_total_draws,on='season_name', how='left')

# %%
df_wins_losses_draws
# Out:
#    season_name  home wins each season  away wins each season  total_wins  \
# 0    2020/2021                     11                     11          22
# 1    2019/2020                     14                      8          22
# 2    2018/2019                     14                     10          24
# 3    2017/2018                     16                     11          27
# 4    2016/2017                     15                     11          26
# 5    2015/2016                     13                     12          25
# 6    2014/2015                     16                     14          30
# 7    2013/2014                     12                      9          21
# 8    2012/2013                     14                     12          26
# 9    2011/2012                     16                     11          27
# 10   2010/2011                     14                     12          26
# 11   2009/2010                     16                     13          29
# 12   2008/2009                     12                     12          24
# 13   2007/2008                     12                      4          16
# 14   2006/2007                      9                      7          16
# 15   2005/2006                      8                      7          15
# 16   2004/2005                      5                      2           7
#
#     home losses each season  away losses each season  total_losses  \
# 0                         3                        4             7
# 1                         1                        4             5
# 2                         1                        1             2
# 3                         0                        0             0
# 4                         1                        2             3
# 5                         2                        2             4
# 6                         2                        2             4
# 7                         1                        3             4
# 8                         0                        2             2
# 9                         1                        2             3
# 10                        1                        1             2
# 11                        0                        1             1
# 12                        1                        2             3
# 13                        1                        4             5
# 14                        0                        5             5
# 15                        1                        0             1
# 16                        0                        0             0
#
#     home draws each season  away draws each season  total_draws
# 0                        4                       2            6
# 1                        2                       4            6
# 2                        3                       5            8
# 3                        3                       6            9
# 4                        2                       3            5
# 5                        1                       3            4
# 6                        1                       3            4
# 7                        2                       4            6
# 8                        1                       3            4
# 9                        1                       6            7
# 10                       1                       4            5
# 11                       0                       5            5
# 12                       2                       2            4
# 13                       1                       6            7
# 14                       4                       1            5
# 15                       1                       0            1
# 16                       0                       0            0

# %%
# Create a bar plot
ax = df_wins_losses_draws.plot(x='season_name', y=['total_wins', 'total_losses', 'total_draws'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('Season ID')
ax.set_ylabel('winsl, losses, and draws')
ax.set_title('Comparison of wins, losses and draws')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# ## Manager's performance

# %% [markdown]
# ### Here we will find how managers have performed
# 1. Total games won
# 2. Total games lost
# 3. Total games draw
# 4. Winning ratio
# 5. Losing ratio

# %% [markdown]
# #### Total managers that Barcelona had from season 2004/2005 to 2020/2021

# %%
df_home_matches.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'home_score', 'away_score',
#        'match_status', 'match_status_360', 'last_updated', 'last_updated_360',
#        'match_week', 'competition_id', 'country_name', 'competition_name',
#        'season_id', 'season_name', 'home_team_id', 'home_team_name',
#        'home_team_gender', 'home_team_group', 'home_team_country_id',
#        'home_team_country_name', 'home_team_managers_id',
#        'home_team_managers_name', 'home_team_managers_nickname',
#        'home_team_managers_dob', 'home_team_managers_country_id',
#        'home_team_managers_country_name', 'away_team_id', 'away_team_name',
#        'away_team_gender', 'away_team_group', 'away_team_country_id',
#        'away_team_country_name', 'away_team_managers_id',
#        'away_team_managers_name', 'away_team_managers_nickname',
#        'away_team_managers_dob', 'away_team_managers_country_id',
#        'away_team_managers_country_name', 'metadata_data_version',
#        'metadata_shot_fidelity_version', 'metadata_xy_fidelity_version',
#        'competition_stage_id', 'competition_stage_name', 'stadium_id',
#        'stadium_name', 'stadium_country_id', 'stadium_country_name',
#        'referee_id', 'referee_name', 'referee_country_id',
#        'referee_country_name', 'home wins each season_x',
#        'home wins each season', 'home losses each season_x',
#        'home losses each season', 'home draws each season_x',
#        'home draws each season'],
#       dtype='object')

# %%
df_home_matches['home_team_managers_name'].unique()
# Out:
# array(['Ronald Koeman', 'Enrique Setién Solar',
#        'Ernesto Valverde Tejedor', 'Luis Enrique Martínez García', nan,
#        'Gerardo Daniel Martino', 'Josep Guardiola i Sala',
#        'Frank Rijkaard'], dtype=object)

# %% [markdown]
# #### finding total wins, total losses and total draws for each manager

# %% [markdown]
# 1. Total wins

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home wins each manager'] = df_home_matches['home_score'] > df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_wins_per_manager = df_home_matches.groupby('home_team_managers_name')['home wins each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_wins_per_manager, on='home_team_managers_name', how='left')

# Rename the column
df_home_matches.rename(columns={'home wins each manager_y': 'home wins each manager'}, inplace=True)

df_home_matches.rename(columns={'home_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/197174709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_home_matches['home wins each manager'] = df_home_matches['home_score'] > df_home_matches['away_score']

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away wins each manager'] = df_away_matches['home_score'] < df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_wins_per_manager = df_away_matches.groupby('away_team_managers_name')['away wins each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_wins_per_manager, on='away_team_managers_name', how='left')

# Rename the column
df_away_matches.rename(columns={'away wins each manager_y': 'away wins each manager'}, inplace=True)

df_away_matches.rename(columns={'away_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/897379021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_away_matches['away wins each manager'] = df_away_matches['home_score'] < df_away_matches['away_score']

# %%
wins_home = df_home_matches[['managers_name','home wins each manager']]
wins_away = df_away_matches[['managers_name','away wins each manager']]

unique_pairs_home_wins = wins_home[['managers_name', 'home wins each manager']].drop_duplicates()
unique_pairs_home_wins.reset_index(inplace=True)
unique_pairs_home_wins = unique_pairs_home_wins.drop('index', axis=1)

unique_pairs_away_wins = wins_away[['managers_name', 'away wins each manager']].drop_duplicates()
unique_pairs_away_wins.reset_index(inplace=True)
unique_pairs_away_wins = unique_pairs_away_wins.drop('index', axis=1)

# %%
df_total_wins_manager = unique_pairs_home_wins.merge(unique_pairs_away_wins,on='managers_name', how='left')

# %%
df_total_wins_manager.dropna()
# Out:
#                   managers_name  home wins each manager  \
# 0                 Ronald Koeman                    11.0
# 1          Enrique Setién Solar                     8.0
# 2      Ernesto Valverde Tejedor                    36.0
# 3  Luis Enrique Martínez García                    43.0
# 5        Gerardo Daniel Martino                    11.0
# 6        Josep Guardiola i Sala                    55.0
# 7                Frank Rijkaard                    31.0
#
#    away wins each manager
# 0                    11.0
# 1                     5.0
# 2                    24.0
# 3                    37.0
# 5                     9.0
# 6                    47.0
# 7                    20.0

# %% [markdown]
# 2. Total losses

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home losses each manager'] = df_home_matches['home_score'] < df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_losses_per_manager = df_home_matches.groupby('home_team_managers_name')['home losses each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_losses_per_manager, on='home_team_managers_name', how='left')

# Rename the column
df_home_matches.rename(columns={'home losses each manager_y': 'home losses each manager'}, inplace=True)

df_home_matches.rename(columns={'home_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/2904284497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_home_matches['home losses each manager'] = df_home_matches['home_score'] < df_home_matches['away_score']

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away losses each manager'] = df_away_matches['home_score'] > df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_losses_per_manager = df_away_matches.groupby('away_team_managers_name')['away losses each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_losses_per_manager, on='away_team_managers_name', how='left')

# Rename the column
df_away_matches.rename(columns={'away losses each manager_y': 'away losses each manager'}, inplace=True)

df_away_matches.rename(columns={'away_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/601267745.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_away_matches['away losses each manager'] = df_away_matches['home_score'] > df_away_matches['away_score']

# %%
losses_home = df_home_matches[['managers_name','home losses each manager']]
losses_away = df_away_matches[['managers_name','away losses each manager']]

unique_pairs_home_losses = losses_home[['managers_name', 'home losses each manager']].drop_duplicates()
unique_pairs_home_losses.reset_index(inplace=True)
unique_pairs_home_losses = unique_pairs_home_losses.drop('index', axis=1)

unique_pairs_away_losses = losses_away[['managers_name', 'away losses each manager']].drop_duplicates()
unique_pairs_away_losses.reset_index(inplace=True)
unique_pairs_away_losses = unique_pairs_away_losses.drop('index', axis=1)

df_total_losses_manager = unique_pairs_home_losses.merge(unique_pairs_away_losses,on='managers_name', how='left')
df_total_losses_manager.dropna()
# Out:
#                   managers_name  home losses each manager  \
# 0                 Ronald Koeman                       3.0
# 1          Enrique Setién Solar                       1.0
# 2      Ernesto Valverde Tejedor                       1.0
# 3  Luis Enrique Martínez García                       5.0
# 5        Gerardo Daniel Martino                       1.0
# 6        Josep Guardiola i Sala                       3.0
# 7                Frank Rijkaard                       1.0
#
#    away losses each manager
# 0                       4.0
# 1                       2.0
# 2                       3.0
# 3                       6.0
# 5                       3.0
# 6                       6.0
# 7                       9.0

# %% [markdown]
# 3. Total draws

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_home_matches['home draws each manager'] = df_home_matches['home_score'] == df_home_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
home_draws_per_manager = df_home_matches.groupby('home_team_managers_name')['home draws each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_home_matches = df_home_matches.merge(home_draws_per_manager, on='home_team_managers_name', how='left')

# Rename the column
df_home_matches.rename(columns={'home draws each manager_y': 'home draws each manager'}, inplace=True)

df_home_matches.rename(columns={'home_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/2533321899.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_home_matches['home draws each manager'] = df_home_matches['home_score'] == df_home_matches['away_score']

# %%
#Filter the DataFrame to include only the rows where the home team wins
df_away_matches['away draws each manager'] = df_away_matches['home_score'] == df_away_matches['away_score']

# Group the home wins by season ID and calculate the number of home wins for each season
away_draws_per_manager = df_away_matches.groupby('away_team_managers_name')['away draws each manager'].sum()

# Merge the calculated home wins per season back to the original DataFrame
df_away_matches = df_away_matches.merge(away_draws_per_manager, on='away_team_managers_name', how='left')

# Rename the column
df_away_matches.rename(columns={'away draws each manager_y': 'away draws each manager'}, inplace=True)

df_away_matches.rename(columns={'away_team_managers_name': 'managers_name'}, inplace=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/2068015547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_away_matches['away draws each manager'] = df_away_matches['home_score'] == df_away_matches['away_score']

# %%
draws_home = df_home_matches[['managers_name','home draws each manager']]
draws_away = df_away_matches[['managers_name','away draws each manager']]

unique_pairs_home_draws = draws_home[['managers_name', 'home draws each manager']].drop_duplicates()
unique_pairs_home_draws.reset_index(inplace=True)
unique_pairs_home_draws = unique_pairs_home_draws.drop('index', axis=1)

unique_pairs_away_draws = draws_away[['managers_name', 'away draws each manager']].drop_duplicates()
unique_pairs_away_draws.reset_index(inplace=True)
unique_pairs_away_draws = unique_pairs_away_draws.drop('index', axis=1)

df_total_draws_manager = unique_pairs_home_draws.merge(unique_pairs_away_draws,on='managers_name', how='left')
df_total_draws_manager.dropna()
# Out:
#                   managers_name  home draws each manager  \
# 0                 Ronald Koeman                      4.0
# 1          Enrique Setién Solar                      1.0
# 2      Ernesto Valverde Tejedor                      7.0
# 3  Luis Enrique Martínez García                      4.0
# 5        Gerardo Daniel Martino                      2.0
# 6        Josep Guardiola i Sala                      4.0
# 7                Frank Rijkaard                      5.0
#
#    away draws each manager
# 0                      2.0
# 1                      2.0
# 2                     13.0
# 3                      9.0
# 5                      4.0
# 6                     17.0
# 7                      7.0

# %%
df_total_draws_manager['total draws'] = df_total_draws_manager['home draws each manager'] + df_total_draws_manager['away draws each manager']

# %%
df_total_losses_manager['total losses'] = df_total_losses_manager['home losses each manager'] + df_total_losses_manager['away losses each manager']

# %%
df_total_wins_manager['total wins'] = df_total_wins_manager['home wins each manager'] + df_total_wins_manager['away wins each manager']

# %%
df_managers =  df_total_draws_manager.merge(df_total_losses_manager, on='managers_name', how='left')

# %%
df_managers = df_managers.merge(df_total_wins_manager, on='managers_name', how='left')

# %%
df_managers.dropna(inplace = True)

# %%
df_managers['total games'] = df_managers['total draws'] + df_managers['total wins'] + df_managers['total losses']

# %%
df_managers['wins percentage'] = df_managers['total wins'] / df_managers['total games']
df_managers['losses percentage'] = df_managers['total losses'] / df_managers['total games']
df_managers['draws percentage'] = df_managers['total draws'] / df_managers['total games']

# %%
df_managers['home wins percentage'] = df_managers['home wins each manager'] / (df_managers['home wins each manager'] + df_managers['away wins each manager']) 
df_managers['away wins percentage'] = df_managers['away wins each manager'] / (df_managers['home wins each manager'] + df_managers['away wins each manager']) 

df_managers['home losses percentage'] = df_managers['home losses each manager'] / (df_managers['home losses each manager'] + df_managers['away losses each manager']) 
df_managers['away losses percentage'] = df_managers['away losses each manager'] / (df_managers['home losses each manager'] + df_managers['away losses each manager']) 

df_managers['home draws percentage'] = df_managers['home draws each manager'] / (df_managers['home draws each manager'] + df_managers['away draws each manager']) 
df_managers['away draws percentage'] = df_managers['away draws each manager'] / (df_managers['home draws each manager'] + df_managers['away draws each manager'])

# %%
df_managers
# Out:
#                   managers_name  home draws each manager  \
# 0                 Ronald Koeman                      4.0
# 1          Enrique Setién Solar                      1.0
# 2      Ernesto Valverde Tejedor                      7.0
# 3  Luis Enrique Martínez García                      4.0
# 5        Gerardo Daniel Martino                      2.0
# 6        Josep Guardiola i Sala                      4.0
# 7                Frank Rijkaard                      5.0
#
#    away draws each manager  total draws  home losses each manager  \
# 0                      2.0          6.0                       3.0
# 1                      2.0          3.0                       1.0
# 2                     13.0         20.0                       1.0
# 3                      9.0         13.0                       5.0
# 5                      4.0          6.0                       1.0
# 6                     17.0         21.0                       3.0
# 7                      7.0         12.0                       1.0
#
#    away losses each manager  total losses  home wins each manager  \
# 0                       4.0           7.0                    11.0
# 1                       2.0           3.0                     8.0
# 2                       3.0           4.0                    36.0
# 3                       6.0          11.0                    43.0
# 5                       3.0           4.0                    11.0
# 6                       6.0           9.0                    55.0
# 7                       9.0          10.0                    31.0
#
#    away wins each manager  total wins  total games  wins percentage  \
# 0                    11.0        22.0         35.0         0.628571
# 1                     5.0        13.0         19.0         0.684211
# 2                    24.0        60.0         84.0         0.714286
# 3                    37.0        80.0        104.0         0.769231
# 5                     9.0        20.0         30.0         0.666667
# 6                    47.0       102.0        132.0         0.772727
# 7                    20.0        51.0         73.0         0.698630
#
#    losses percentage  draws percentage  home wins percentage  \
# 0           0.200000          0.171429              0.500000
# 1           0.157895          0.157895              0.615385
# 2           0.047619          0.238095              0.600000
# 3           0.105769          0.125000              0.537500
# 5           0.133333          0.200000              0.550000
# 6           0.068182          0.159091              0.539216
# 7           0.136986          0.164384              0.607843
#
#    away wins percentage  home losses percentage  away losses percentage  \
# 0              0.500000                0.428571                0.571429
# 1              0.384615                0.333333                0.666667
# 2              0.400000                0.250000                0.750000
# 3              0.462500                0.454545                0.545455
# 5              0.450000                0.250000                0.750000
# 6              0.460784                0.333333                0.666667
# 7              0.392157                0.100000                0.900000
#
#    home draws percentage  away draws percentage
# 0               0.666667               0.333333
# 1               0.333333               0.666667
# 2               0.350000               0.650000
# 3               0.307692               0.692308
# 5               0.333333               0.666667
# 6               0.190476               0.809524
# 7               0.416667               0.583333

# %% [markdown]
# Visualization
#
# 1. Wins, draws and losses of each manager
# 2. percentage of wins, draws and losses of each manager
# 2. Home wins percentage, away wins percentage for each manager
# 3. Home losses percentage, away losses percentage for each manager
# 4. Home draws percentage, away draws percentage for each manager

# %%
# Create a bar plot
ax = df_managers.plot(x='managers_name', y=['total wins', 'total losses', 'total draws'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('manager name')
ax.set_ylabel('wins, losses, and draws')
ax.set_title('Comparison of wins, losses and draws')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Create a bar plot
ax = df_managers.plot(x='managers_name', y=['wins percentage', 'losses percentage', 'draws percentage'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('manager name')
ax.set_ylabel('wins, losses, and draws')
ax.set_title('Comparison of wins, losses and draws percentage')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Create a bar plot
ax = df_managers.plot(x='managers_name', y=['home wins percentage', 'away wins percentage'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('manager name')
ax.set_ylabel('home wins, away wins')
ax.set_title('Comparison of home vs away wins percentage')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Create a bar plot
ax = df_managers.plot(x='managers_name', y=['home losses percentage', 'away losses percentage'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('manager name')
ax.set_ylabel('home losses, away losses')
ax.set_title('Comparison of home vs away losses percentage')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Create a bar plot
ax = df_managers.plot(x='managers_name', y=['home draws percentage', 'away draws percentage'], kind='bar', rot=0)

# Set plot labels and title
ax.set_xlabel('manager name')
ax.set_ylabel('home draws, away draws')
ax.set_title('Comparison of home vs away draws percentage')

# Adjust x-axis label rotation
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# ## Season wise analysis with events data
#
# 1. Shots heatmap
# 2. Goals heatmap
# 3. Defensive actions heatmap
# 4. Dangerous passes heatmap
# 5. Assists heatmap
# 6. Average xG bar plot
# 7. Passing network for each season
# 8. Penalty goals barplot
# 9. Direct FreeKick goals barplot

# %% [markdown]
# #### First thing that we need to do is to find the relevant match data.
# We will get event data for home matches and away matches

# %%
#df_event = parser.event("match id")
df_laliga_events = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events(row):
    current_match_id = row['match_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_event = parser.event(match_id=current_match_id)
    return df_event

# Iterate through the rows and fetch matches
for index, row in df_laliga_matches.iterrows():
    events = fetch_events(row)
    # Append the matches to df_championsLeague_matches
    df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# ...
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/890514751.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_laliga_events = df_laliga_events.append(events, ignore_index=True)

# %%
df_laliga_events.to_csv('laliga_events.csv', index=False)

# %%
df_home_events = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events_fromMatchID(row):
    current_match_id = row['match_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_event = df_laliga_events[df_laliga_events['match_id'] == current_match_id]
    return df_event

# Iterate through the rows and fetch matches
for index, row in df_home_matches.iterrows():
    events = fetch_events_fromMatchID(row)
    # Append the matches to df_championsLeague_matches
    df_home_events = df_home_events.append(events, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/67024143.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_home_events = df_home_events.append(events, ignore_index=True)

# %%
df_home_events.to_csv('laliga_home_events.csv', index=False)

# %%
df_away_events = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events_fromMatchID(row):
    current_match_id = row['match_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_event = df_laliga_events[df_laliga_events['match_id'] == current_match_id]
    return df_event

# Iterate through the rows and fetch matches
for index, row in df_away_matches.iterrows():
    events = fetch_events_fromMatchID(row)
    # Append the matches to df_championsLeague_matches
    df_away_events = df_away_events.append(events, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/4160391217.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_away_events = df_away_events.append(events, ignore_index=True)

# %%
df_away_events.to_csv('laliga_away_events.csv', index=False)

# %% [markdown]
# ### Now that we have got the events data for home and away games,  we will have to perform our analysis for each season

# %% [markdown]
# #### Season ID - 1  Season Name - 2017/2018

# %%
df_season1_home = df_home_matches[df_home_matches['season_id'] == 1]

# %%
df_season1_away = df_away_matches[df_away_matches['season_id'] == 1]

# %%
df_season1 = df_season1_home.append(df_season1_away,ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/1248971606.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_season1 = df_season1_home.append(df_season1_away,ignore_index=True)

# %%
df_season1_home_events = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events_fromMatchID(row):
    current_match_id = row['match_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_event = df_home_events[df_home_events['match_id'] == current_match_id]
    return df_event

# Iterate through the rows and fetch matches
for index, row in df_season1_home.iterrows():
    events = fetch_events_fromMatchID(row)
    # Append the matches to df_championsLeague_matches
    df_season1_home_events = df_season1_home_events.append(events, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/2342296632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_season1_home_events = df_season1_home_events.append(events, ignore_index=True)

# %%
df_season1_home_events
# Out:
#                                           id  index  period        timestamp  \
# 0       2f8319f2-f34c-47fd-977b-332324d7d86c    1.0     1.0         00:00:00
# 1       43fae5ba-b810-4f74-a16d-cd176c51664f    2.0     1.0         00:00:00
# 2       67ef9f5e-fa09-47a3-ba34-9db104d76596    3.0     1.0         00:00:00
# 3       77f21766-088e-4b62-b9dd-e32c977f2c5d    4.0     1.0         00:00:00
# 4       884e0535-26fd-4299-b5e6-389f563e0c54    5.0     1.0  00:00:00.388000
# ...                                      ...    ...     ...              ...
# 220880  2c00b3b2-1a43-4afa-a08e-6bc33ca34dfc    NaN     NaN              NaN
# 220881  2c00b3b2-1a43-4afa-a08e-6bc33ca34dfc    NaN     NaN              NaN
# 220882  2c00b3b2-1a43-4afa-a08e-6bc33ca34dfc    NaN     NaN              NaN
# 220883  2c00b3b2-1a43-4afa-a08e-6bc33ca34dfc    NaN     NaN              NaN
# 220884  2c00b3b2-1a43-4afa-a08e-6bc33ca34dfc    NaN     NaN              NaN
#
#         minute  second  possession  duration  match_id  type_id  ...  \
# 0          0.0     0.0         1.0  0.000000      9880     35.0  ...
# 1          0.0     0.0         1.0  0.000000      9880     35.0  ...
# 2          0.0     0.0         1.0  0.000000      9880     18.0  ...
# 3          0.0     0.0         1.0  0.000000      9880     18.0  ...
# 4          0.0     0.0         2.0  0.925053      9880     30.0  ...
# ...        ...     ...         ...       ...       ...      ...  ...
# 220880     NaN     NaN         NaN       NaN      9726      NaN  ...
# 220881     NaN     NaN         NaN       NaN      9726      NaN  ...
# 220882     NaN     NaN         NaN       NaN      9726      NaN  ...
# 220883     NaN     NaN         NaN       NaN      9726      NaN  ...
# 220884     NaN     NaN         NaN       NaN      9726      NaN  ...
#
#        foul_committed_penalty  foul_won_penalty shot_open_goal  \
# 0                         NaN               NaN            NaN
# 1                         NaN               NaN            NaN
# 2                         NaN               NaN            NaN
# 3                         NaN               NaN            NaN
# 4                         NaN               NaN            NaN
# ...                       ...               ...            ...
# 220880                    NaN               NaN            NaN
# 220881                    NaN               NaN            NaN
# 220882                    NaN               NaN            NaN
# 220883                    NaN               NaN            NaN
# 220884                    NaN               NaN            NaN
#
#         block_save_block dribble_no_touch  shot_redirect shot_follows_dribble  \
# 0                    NaN              NaN            NaN                  NaN
# 1                    NaN              NaN            NaN                  NaN
# 2                    NaN              NaN            NaN                  NaN
# 3                    NaN              NaN            NaN                  NaN
# 4                    NaN              NaN            NaN                  NaN
# ...                  ...              ...            ...                  ...
# 220880               NaN              NaN            NaN                  NaN
# 220881               NaN              NaN            NaN                  NaN
# 220882               NaN              NaN            NaN                  NaN
# 220883               NaN              NaN            NaN                  NaN
# 220884               NaN              NaN            NaN                  NaN
#
#         half_start_late_video_start  player_off_permanent  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
# ...                             ...                   ...
# 220880                          NaN                   NaN
# 220881                          NaN                   NaN
# 220882                          NaN                   NaN
# 220883                          NaN                   NaN
# 220884                          NaN                   NaN
#
#        half_end_early_video_end
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 220880                      NaN
# 220881                      NaN
# 220882                      NaN
# 220883                      NaN
# 220884                      NaN
#
# [220885 rows x 96 columns]

# %%
df_season1_away_events = pd.DataFrame()

# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events_fromMatchID(row):
    current_match_id = row['match_id']
    # Your logic or function based on 'competition_id' and 'season_id' values
    df_event = df_away_events[df_away_events['match_id'] == current_match_id]
    return df_event

# Iterate through the rows and fetch matches
for index, row in df_season1_away.iterrows():
    events = fetch_events_fromMatchID(row)
    # Append the matches to df_championsLeague_matches
    df_season1_away_events = df_season1_away_events.append(events, ignore_index=True)
# Out:
# /var/folders/dq/pg0mssxn6yzdwtcdrwnt0bs80000gn/T/ipykernel_24196/3096687514.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_season1_away_events = df_season1_away_events.append(events, ignore_index=True)

# %%
df_season1_away_events
# Out:
#                                           id  index  period        timestamp  \
# 0       219a12b0-8168-4d56-846a-0d60c7fad617    1.0     1.0         00:00:00
# 1       abf649e0-a048-4cf5-9271-e8e460cde53d    2.0     1.0         00:00:00
# 2       3c3bac9a-5e6c-41d8-9235-d5f1b700d71f    3.0     1.0         00:00:00
# 3       49ca8c60-68dd-4b00-8ad6-ea220a7fdb94    4.0     1.0         00:00:00
# 4       ed7efc2d-36f9-4293-b7b6-9158eb985d1e    5.0     1.0  00:00:00.338000
# ...                                      ...    ...     ...              ...
# 191981  99743d70-287d-4160-9deb-b3ca6ef28f6f    NaN     NaN              NaN
# 191982  99743d70-287d-4160-9deb-b3ca6ef28f6f    NaN     NaN              NaN
# 191983  99743d70-287d-4160-9deb-b3ca6ef28f6f    NaN     NaN              NaN
# 191984  99743d70-287d-4160-9deb-b3ca6ef28f6f    NaN     NaN              NaN
# 191985  99743d70-287d-4160-9deb-b3ca6ef28f6f    NaN     NaN              NaN
#
#         minute  second  possession  duration  match_id  type_id  ...  \
# 0          0.0     0.0         1.0  0.000000      9912     35.0  ...
# 1          0.0     0.0         1.0  0.000000      9912     35.0  ...
# 2          0.0     0.0         1.0  0.000000      9912     18.0  ...
# 3          0.0     0.0         1.0  0.000000      9912     18.0  ...
# 4          0.0     0.0         2.0  0.666626      9912     30.0  ...
# ...        ...     ...         ...       ...       ...      ...  ...
# 191981     NaN     NaN         NaN       NaN      9889      NaN  ...
# 191982     NaN     NaN         NaN       NaN      9889      NaN  ...
# 191983     NaN     NaN         NaN       NaN      9889      NaN  ...
# 191984     NaN     NaN         NaN       NaN      9889      NaN  ...
# 191985     NaN     NaN         NaN       NaN      9889      NaN  ...
#
#        foul_committed_penalty  foul_won_penalty shot_open_goal  \
# 0                         NaN               NaN            NaN
# 1                         NaN               NaN            NaN
# 2                         NaN               NaN            NaN
# 3                         NaN               NaN            NaN
# 4                         NaN               NaN            NaN
# ...                       ...               ...            ...
# 191981                    NaN               NaN            NaN
# 191982                    NaN               NaN            NaN
# 191983                    NaN               NaN            NaN
# 191984                    NaN               NaN            NaN
# 191985                    NaN               NaN            NaN
#
#         block_save_block dribble_no_touch  shot_redirect shot_follows_dribble  \
# 0                    NaN              NaN            NaN                  NaN
# 1                    NaN              NaN            NaN                  NaN
# 2                    NaN              NaN            NaN                  NaN
# 3                    NaN              NaN            NaN                  NaN
# 4                    NaN              NaN            NaN                  NaN
# ...                  ...              ...            ...                  ...
# 191981               NaN              NaN            NaN                  NaN
# 191982               NaN              NaN            NaN                  NaN
# 191983               NaN              NaN            NaN                  NaN
# 191984               NaN              NaN            NaN                  NaN
# 191985               NaN              NaN            NaN                  NaN
#
#         half_start_late_video_start  player_off_permanent  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
# ...                             ...                   ...
# 191981                          NaN                   NaN
# 191982                          NaN                   NaN
# 191983                          NaN                   NaN
# 191984                          NaN                   NaN
# 191985                          NaN                   NaN
#
#        half_end_early_video_end
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 191981                      NaN
# 191982                      NaN
# 191983                      NaN
# 191984                      NaN
# 191985                      NaN
#
# [191986 rows x 96 columns]

# %% [markdown]
# #### Now that we have season 1 (2017-2018) matches events, we can proceed with our analysis

# %% [markdown]
# ### 1. Shots heatmap

# %%
home_shots = df_season1_home_events.loc[df_season1_home_events['type_name'] == 'Shot'].set_index('id')

# %%
away_shots = df_season1_away_events.loc[df_season1_away_events['type_name'] == 'Shot'].set_index('id')

# %% [markdown]
# home_shots contains all shots events for both home and away teams
# But since we are plotting heat map for home team shots, we should consider home_shots for only home_team which in this case is BARCELONA

# %%
barcelona_shots_home = home_shots[home_shots['team_name'] == team]

# %%
from mplsoccer import Pitch, Sbopen, VerticalPitch

#create pitch
pitch = Pitch(line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)


#plot them - if shot ended with Goal - alpha 1 and add name
for i, row in barcelona_shots_home.iterrows():
    if row["outcome_name"] == 'Goal':
    #make circle
       pitch.scatter(row.x, row.y, alpha = 1, s = 500, color = "red", ax=ax['pitch'])
    else:
       pitch.scatter(row.x, row.y, alpha = 0.2, s = 500, color = "red", ax=ax['pitch'])

# %%
barcelona_shots_away = away_shots[away_shots['team_name'] == team]

# %%
#create pitch
pitch = Pitch(line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)


#plot them - if shot ended with Goal - alpha 1 and add name
for i, row in barcelona_shots_away.iterrows():
    if row["outcome_name"] == 'Goal':
    #make circle
       pitch.scatter(row.x, row.y, alpha = 1, s = 500, color = "red", ax=ax['pitch'])
    else:
       pitch.scatter(row.x, row.y, alpha = 0.2, s = 500, color = "red", ax=ax['pitch'])

# %%
no_games = len(barcelona_shots_away)

# %%
#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(barcelona_shots_away.x, barcelona_shots_away.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Shots attempted by ' + team + " per game for away games", fontsize = 30)
plt.show()

# %%
no_games = len(barcelona_shots_home)

#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(barcelona_shots_home.x, barcelona_shots_home.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Shots attempted by ' + team + " per game for home games", fontsize = 30)
plt.show()

# %% [markdown]
# ### 2. Goals Heatmap

# %%
home_goals = barcelona_shots_home.loc[barcelona_shots_home['outcome_name'] == 'Goal']
away_goals = df_season1_away_events.loc[df_season1_away_events['outcome_name'] == 'Goal']

barcelona_goals_home = home_goals[home_goals['team_name'] == team]
barcelona_goals_away = away_goals[away_goals['team_name'] == team]

# %%
home_goals
# Out:
#                                        index  period        timestamp  minute  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f   700.0     1.0  00:14:07.045000    14.0
# ad6595c0-e69a-4428-a902-f0ad4139e6ee  2236.0     2.0  00:05:39.548000    50.0
# f38c74de-91ba-44b1-b95b-fc7e421536ea   472.0     1.0  00:09:22.688000     9.0
# 0ca38903-2d66-4306-80db-ce106bc445b7  2370.0     2.0  00:06:50.314000    51.0
# e472e061-bb70-413a-94e3-1dc1378437b6   356.0     1.0  00:07:31.106000     7.0
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27  1299.0     1.0  00:29:39.811000    29.0
# 29a52984-b52d-4cd7-93f4-0f6d332997db  2202.0     2.0  00:03:23.342000    48.0
# b86b941b-c27d-4e90-8b69-ee77dffa1646  3185.0     2.0  00:24:57.265000    69.0
# ddf62112-8330-4164-9b7e-ab34f2f9fa20  3469.0     2.0  00:31:33.973000    76.0
# d4705b10-9d1a-4ab1-8b79-52d63507923f   881.0     1.0  00:20:01.137000    20.0
# a22c750f-c396-4218-9973-2fdc3a104169  1566.0     1.0  00:37:11.830000    37.0
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc  2252.0     2.0  00:07:45.749000    52.0
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624  2500.0     2.0  00:13:41.287000    58.0
# 9e13945c-7e87-42b3-899a-2d19cd039a5f  2615.0     2.0  00:16:37.326000    61.0
# ba112504-ee72-48ca-ab62-c84f8b4c73fc  3546.0     2.0  00:41:57.571000    86.0
# bdce1e25-2811-47c7-ac12-4f1919235204  1752.0     1.0  00:38:03.032000    38.0
# e5af85bf-bee4-4c27-95fa-8c403a8639a8   578.0     1.0  00:10:08.219000    10.0
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700   773.0     1.0  00:15:46.225000    15.0
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c  2112.0     1.0  00:44:25.674000    44.0
# 0cd2f622-8de5-40b3-89c3-258e2a09101a  3908.0     2.0  00:41:44.664000    86.0
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b  4090.0     2.0  00:47:50.648000    92.0
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60   461.0     1.0  00:11:35.890000    11.0
# c65948b2-62e6-4aad-83f0-58720b99c6f1  1428.0     1.0  00:37:09.382000    37.0
# 47f6ed32-5527-4d40-972a-5c93b4efeed1  3699.0     2.0  00:47:15.743000    92.0
# c09c6e64-612b-4ba2-931e-5cde922a24b3  1176.0     1.0  00:25:09.245000    25.0
# 5656d749-a0c6-4469-bdea-a07ab0919ba9  1492.0     1.0  00:34:49.293000    34.0
# 5f1f5de5-115f-484d-95c4-19fba32feefc  2698.0     2.0  00:21:10.123000    66.0
# 30096480-4544-4ef5-a7e3-ac42e2298f5f  3337.0     2.0  00:41:17.948000    86.0
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695  3462.0     2.0  00:44:52.450000    89.0
# bd5ebd93-b60e-4eed-9854-006efaa841d1  1262.0     1.0  00:26:22.633000    26.0
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74  1477.0     1.0  00:31:35.670000    31.0
# ad41f580-4dc5-4214-895a-ea11a2675e54  3636.0     2.0  00:41:25.615000    86.0
# a1969a60-46db-4266-923f-b8ee86f9919b   984.0     1.0  00:21:48.292000    21.0
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6  3012.0     2.0  00:16:48.907000    61.0
# 59b693ed-2d6d-4811-96e3-ba421c414129  1027.0     1.0  00:22:12.088000    22.0
# 649cb11c-488b-42c8-b03c-998c88748415  2936.0     2.0  00:19:22.434000    64.0
# eb628fbd-7857-4597-826b-ccb9b52a78cc   139.0     1.0  00:01:52.524000     1.0
# 9de54125-8f04-4707-bedb-03654376cdc0  2454.0     2.0  00:10:40.208000    55.0
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9  1146.0     1.0  00:25:27.721000    25.0
# 25a599c1-b26c-40d0-8574-234b2647e707   199.0     1.0  00:04:22.398000     4.0
# 79503977-6e91-4b5b-9460-d1f0faa6bccb  1187.0     1.0  00:29:24.111000    29.0
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382  1362.0     1.0  00:35:59.195000    35.0
# ed4e4cf4-a3a8-4482-9032-df67e468450c  1617.0     1.0  00:43:38.669000    43.0
# fbab9669-36ea-48e4-9143-0f5175837976  2565.0     2.0  00:20:26.561000    65.0
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400  2914.0     2.0  00:30:46.625000    75.0
# 5cfcb44f-4529-47c2-9228-f8f3c98791be  2878.0     2.0  00:26:26.112000    71.0
# 6d8b260c-f12a-4328-bff1-6a2cafb88604  3224.0     2.0  00:38:15.520000    83.0
# 07bf2ae2-7de1-4c63-938a-8ca0792de661  2300.0     2.0  00:11:21.786000    56.0
# 85cee35b-08af-4e6e-958a-74cbf2f4562f  1348.0     1.0  00:28:03.757000    28.0
# 3da44fc7-6bac-4aaf-9848-22abab0865f8  1812.0     1.0  00:40:13.165000    40.0
# ee4ac7bb-2cd9-401f-80a1-53d58327a549  2137.0     2.0  00:01:23.581000    46.0
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4  3280.0     2.0  00:29:33.085000    74.0
#
#                                       second  possession  duration  match_id  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f     7.0        26.0  0.336449      9880
# ad6595c0-e69a-4428-a902-f0ad4139e6ee    39.0       112.0  0.572371      9880
# f38c74de-91ba-44b1-b95b-fc7e421536ea    22.0        25.0  0.451381      9924
# 0ca38903-2d66-4306-80db-ce106bc445b7    50.0       102.0  0.893583      9924
# e472e061-bb70-413a-94e3-1dc1378437b6    31.0        15.0  0.832466      9855
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27    39.0        56.0  0.816699      9855
# 29a52984-b52d-4cd7-93f4-0f6d332997db    23.0       100.0  0.415575      9636
# b86b941b-c27d-4e90-8b69-ee77dffa1646    57.0       140.0  0.357679      9636
# ddf62112-8330-4164-9b7e-ab34f2f9fa20    33.0       149.0  0.487347      9636
# d4705b10-9d1a-4ab1-8b79-52d63507923f     1.0        45.0  0.735106      9609
# a22c750f-c396-4218-9973-2fdc3a104169    11.0        81.0  0.357530      9609
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc    45.0       116.0  0.512289      9609
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624    41.0       124.0  0.835625      9609
# 9e13945c-7e87-42b3-899a-2d19cd039a5f    37.0       129.0  1.268289      9609
# ba112504-ee72-48ca-ab62-c84f8b4c73fc    57.0       175.0  0.774379      9609
# bdce1e25-2811-47c7-ac12-4f1919235204     3.0        70.0  0.946428      9575
# e5af85bf-bee4-4c27-95fa-8c403a8639a8     8.0        26.0  0.238000      9928
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700    46.0        32.0  0.366000      9928
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c    25.0        92.0  0.795000      9928
# 0cd2f622-8de5-40b3-89c3-258e2a09101a    44.0       184.0  0.100000      9928
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b    50.0       193.0  1.015000      9928
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60    35.0        23.0  1.392024      9742
# c65948b2-62e6-4aad-83f0-58720b99c6f1     9.0        73.0  0.148259      9742
# 47f6ed32-5527-4d40-972a-5c93b4efeed1    15.0       172.0  0.536921      9742
# c09c6e64-612b-4ba2-931e-5cde922a24b3     9.0        45.0  0.480919      9592
# 5656d749-a0c6-4469-bdea-a07ab0919ba9    49.0        60.0  0.667974      9592
# 5f1f5de5-115f-484d-95c4-19fba32feefc    10.0       121.0  0.689000      9592
# 30096480-4544-4ef5-a7e3-ac42e2298f5f    17.0       159.0  0.474284      9592
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695    52.0       164.0  0.758077      9592
# bd5ebd93-b60e-4eed-9854-006efaa841d1    22.0        43.0  1.243681      9870
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74    35.0        54.0  1.169748      9870
# ad41f580-4dc5-4214-895a-ea11a2675e54    25.0       169.0  1.032558      9870
# a1969a60-46db-4266-923f-b8ee86f9919b    48.0        35.0  0.589814      9700
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6    48.0       124.0  0.736717      9700
# 59b693ed-2d6d-4811-96e3-ba421c414129    12.0        59.0  1.172531      9673
# 649cb11c-488b-42c8-b03c-998c88748415    22.0       145.0  0.321613      9673
# eb628fbd-7857-4597-826b-ccb9b52a78cc    52.0         3.0  0.564080      9650
# 9de54125-8f04-4707-bedb-03654376cdc0    40.0       116.0  0.047129      9650
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9    27.0        56.0  1.205676      9837
# 25a599c1-b26c-40d0-8574-234b2647e707    22.0         5.0  0.811413      9811
# 79503977-6e91-4b5b-9460-d1f0faa6bccb    24.0        59.0  0.674935      9811
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382    59.0        68.0  1.007716      9811
# ed4e4cf4-a3a8-4482-9032-df67e468450c    38.0        83.0  0.333399      9811
# fbab9669-36ea-48e4-9143-0f5175837976    26.0       132.0  1.241149      9811
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400    46.0       150.0  0.561000      9811
# 5cfcb44f-4529-47c2-9228-f8f3c98791be    26.0       157.0  0.748552      9774
# 6d8b260c-f12a-4328-bff1-6a2cafb88604    15.0       189.0  1.069893      9774
# 07bf2ae2-7de1-4c63-938a-8ca0792de661    21.0       108.0  1.310252      9948
# 85cee35b-08af-4e6e-958a-74cbf2f4562f     3.0        60.0  0.361650      9726
# 3da44fc7-6bac-4aaf-9848-22abab0865f8    13.0        89.0  0.913934      9726
# ee4ac7bb-2cd9-401f-80a1-53d58327a549    23.0       105.0  0.358798      9726
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4    33.0       161.0  0.301472      9726
#
#                                       type_id type_name  ...  \
# id                                                       ...
# 7b02c827-3580-4149-9912-216ce2bd544f     16.0      Shot  ...
# ad6595c0-e69a-4428-a902-f0ad4139e6ee     16.0      Shot  ...
# f38c74de-91ba-44b1-b95b-fc7e421536ea     16.0      Shot  ...
# 0ca38903-2d66-4306-80db-ce106bc445b7     16.0      Shot  ...
# e472e061-bb70-413a-94e3-1dc1378437b6     16.0      Shot  ...
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27     16.0      Shot  ...
# 29a52984-b52d-4cd7-93f4-0f6d332997db     16.0      Shot  ...
# b86b941b-c27d-4e90-8b69-ee77dffa1646     16.0      Shot  ...
# ddf62112-8330-4164-9b7e-ab34f2f9fa20     16.0      Shot  ...
# d4705b10-9d1a-4ab1-8b79-52d63507923f     16.0      Shot  ...
# a22c750f-c396-4218-9973-2fdc3a104169     16.0      Shot  ...
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc     16.0      Shot  ...
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624     16.0      Shot  ...
# 9e13945c-7e87-42b3-899a-2d19cd039a5f     16.0      Shot  ...
# ba112504-ee72-48ca-ab62-c84f8b4c73fc     16.0      Shot  ...
# bdce1e25-2811-47c7-ac12-4f1919235204     16.0      Shot  ...
# e5af85bf-bee4-4c27-95fa-8c403a8639a8     16.0      Shot  ...
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700     16.0      Shot  ...
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c     16.0      Shot  ...
# 0cd2f622-8de5-40b3-89c3-258e2a09101a     16.0      Shot  ...
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b     16.0      Shot  ...
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60     16.0      Shot  ...
# c65948b2-62e6-4aad-83f0-58720b99c6f1     16.0      Shot  ...
# 47f6ed32-5527-4d40-972a-5c93b4efeed1     16.0      Shot  ...
# c09c6e64-612b-4ba2-931e-5cde922a24b3     16.0      Shot  ...
# 5656d749-a0c6-4469-bdea-a07ab0919ba9     16.0      Shot  ...
# 5f1f5de5-115f-484d-95c4-19fba32feefc     16.0      Shot  ...
# 30096480-4544-4ef5-a7e3-ac42e2298f5f     16.0      Shot  ...
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695     16.0      Shot  ...
# bd5ebd93-b60e-4eed-9854-006efaa841d1     16.0      Shot  ...
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74     16.0      Shot  ...
# ad41f580-4dc5-4214-895a-ea11a2675e54     16.0      Shot  ...
# a1969a60-46db-4266-923f-b8ee86f9919b     16.0      Shot  ...
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6     16.0      Shot  ...
# 59b693ed-2d6d-4811-96e3-ba421c414129     16.0      Shot  ...
# 649cb11c-488b-42c8-b03c-998c88748415     16.0      Shot  ...
# eb628fbd-7857-4597-826b-ccb9b52a78cc     16.0      Shot  ...
# 9de54125-8f04-4707-bedb-03654376cdc0     16.0      Shot  ...
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9     16.0      Shot  ...
# 25a599c1-b26c-40d0-8574-234b2647e707     16.0      Shot  ...
# 79503977-6e91-4b5b-9460-d1f0faa6bccb     16.0      Shot  ...
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382     16.0      Shot  ...
# ed4e4cf4-a3a8-4482-9032-df67e468450c     16.0      Shot  ...
# fbab9669-36ea-48e4-9143-0f5175837976     16.0      Shot  ...
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400     16.0      Shot  ...
# 5cfcb44f-4529-47c2-9228-f8f3c98791be     16.0      Shot  ...
# 6d8b260c-f12a-4328-bff1-6a2cafb88604     16.0      Shot  ...
# 07bf2ae2-7de1-4c63-938a-8ca0792de661     16.0      Shot  ...
# 85cee35b-08af-4e6e-958a-74cbf2f4562f     16.0      Shot  ...
# 3da44fc7-6bac-4aaf-9848-22abab0865f8     16.0      Shot  ...
# ee4ac7bb-2cd9-401f-80a1-53d58327a549     16.0      Shot  ...
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4     16.0      Shot  ...
#
#                                       foul_committed_penalty foul_won_penalty  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f                     NaN              NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee                     NaN              NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea                     NaN              NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7                     NaN              NaN
# e472e061-bb70-413a-94e3-1dc1378437b6                     NaN              NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27                     NaN              NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db                     NaN              NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646                     NaN              NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20                     NaN              NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f                     NaN              NaN
# a22c750f-c396-4218-9973-2fdc3a104169                     NaN              NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc                     NaN              NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624                     NaN              NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f                     NaN              NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc                     NaN              NaN
# bdce1e25-2811-47c7-ac12-4f1919235204                     NaN              NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8                     NaN              NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700                     NaN              NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c                     NaN              NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a                     NaN              NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b                     NaN              NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60                     NaN              NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1                     NaN              NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1                     NaN              NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3                     NaN              NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9                     NaN              NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc                     NaN              NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f                     NaN              NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695                     NaN              NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1                     NaN              NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74                     NaN              NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54                     NaN              NaN
# a1969a60-46db-4266-923f-b8ee86f9919b                     NaN              NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6                     NaN              NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129                     NaN              NaN
# 649cb11c-488b-42c8-b03c-998c88748415                     NaN              NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc                     NaN              NaN
# 9de54125-8f04-4707-bedb-03654376cdc0                     NaN              NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9                     NaN              NaN
# 25a599c1-b26c-40d0-8574-234b2647e707                     NaN              NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb                     NaN              NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382                     NaN              NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c                     NaN              NaN
# fbab9669-36ea-48e4-9143-0f5175837976                     NaN              NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400                     NaN              NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be                     NaN              NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604                     NaN              NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661                     NaN              NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f                     NaN              NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8                     NaN              NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549                     NaN              NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4                     NaN              NaN
#
#                                       shot_open_goal block_save_block  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f             NaN              NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee             NaN              NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea             NaN              NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7             NaN              NaN
# e472e061-bb70-413a-94e3-1dc1378437b6             NaN              NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27             NaN              NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db             NaN              NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646            True              NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20             NaN              NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f             NaN              NaN
# a22c750f-c396-4218-9973-2fdc3a104169             NaN              NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc             NaN              NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624             NaN              NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f             NaN              NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc             NaN              NaN
# bdce1e25-2811-47c7-ac12-4f1919235204             NaN              NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8             NaN              NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700            True              NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c             NaN              NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a            True              NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b             NaN              NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60             NaN              NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1             NaN              NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1             NaN              NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3             NaN              NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9             NaN              NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc             NaN              NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f             NaN              NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695             NaN              NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1             NaN              NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74             NaN              NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54             NaN              NaN
# a1969a60-46db-4266-923f-b8ee86f9919b             NaN              NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6             NaN              NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129             NaN              NaN
# 649cb11c-488b-42c8-b03c-998c88748415             NaN              NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc             NaN              NaN
# 9de54125-8f04-4707-bedb-03654376cdc0             NaN              NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9             NaN              NaN
# 25a599c1-b26c-40d0-8574-234b2647e707             NaN              NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb             NaN              NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382             NaN              NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c             NaN              NaN
# fbab9669-36ea-48e4-9143-0f5175837976             NaN              NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400             NaN              NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be             NaN              NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604             NaN              NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661             NaN              NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f             NaN              NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8            True              NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549             NaN              NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4            True              NaN
#
#                                       dribble_no_touch shot_redirect  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f               NaN           NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee               NaN           NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea               NaN           NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7               NaN           NaN
# e472e061-bb70-413a-94e3-1dc1378437b6               NaN           NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27               NaN           NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db               NaN           NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646               NaN           NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20               NaN           NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f               NaN           NaN
# a22c750f-c396-4218-9973-2fdc3a104169               NaN           NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc               NaN           NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624               NaN           NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f               NaN           NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc               NaN           NaN
# bdce1e25-2811-47c7-ac12-4f1919235204               NaN           NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8               NaN           NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700               NaN           NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c               NaN           NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a               NaN           NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b               NaN           NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60               NaN           NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1               NaN           NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1               NaN           NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3               NaN           NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9               NaN           NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc               NaN           NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f               NaN           NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695               NaN           NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1               NaN           NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74               NaN           NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54               NaN           NaN
# a1969a60-46db-4266-923f-b8ee86f9919b               NaN           NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6               NaN           NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129               NaN           NaN
# 649cb11c-488b-42c8-b03c-998c88748415               NaN           NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc               NaN           NaN
# 9de54125-8f04-4707-bedb-03654376cdc0               NaN           NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9               NaN           NaN
# 25a599c1-b26c-40d0-8574-234b2647e707               NaN           NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb               NaN           NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382               NaN           NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c               NaN           NaN
# fbab9669-36ea-48e4-9143-0f5175837976               NaN           NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400               NaN           NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be               NaN           NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604               NaN           NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661               NaN           NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f               NaN           NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8               NaN           NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549               NaN           NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4               NaN           NaN
#
#                                       shot_follows_dribble  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f                   NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee                   NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea                   NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7                   NaN
# e472e061-bb70-413a-94e3-1dc1378437b6                   NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27                   NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db                   NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646                   NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20                   NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f                   NaN
# a22c750f-c396-4218-9973-2fdc3a104169                   NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc                   NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624                   NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f                   NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc                   NaN
# bdce1e25-2811-47c7-ac12-4f1919235204                   NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8                   NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700                   NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c                   NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a                   NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b                   NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60                   NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1                   NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1                   NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3                   NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9                   NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc                   NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f                   NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695                   NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1                   NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74                   NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54                   NaN
# a1969a60-46db-4266-923f-b8ee86f9919b                   NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6                   NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129                   NaN
# 649cb11c-488b-42c8-b03c-998c88748415                   NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc                   NaN
# 9de54125-8f04-4707-bedb-03654376cdc0                   NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9                   NaN
# 25a599c1-b26c-40d0-8574-234b2647e707                   NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb                   NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382                   NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c                   NaN
# fbab9669-36ea-48e4-9143-0f5175837976                   NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400                   NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be                   NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604                   NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661                   NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f                   NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8                   NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549                   NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4                   NaN
#
#                                       half_start_late_video_start  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f                          NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee                          NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea                          NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7                          NaN
# e472e061-bb70-413a-94e3-1dc1378437b6                          NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27                          NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db                          NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646                          NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20                          NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f                          NaN
# a22c750f-c396-4218-9973-2fdc3a104169                          NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc                          NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624                          NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f                          NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc                          NaN
# bdce1e25-2811-47c7-ac12-4f1919235204                          NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8                          NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700                          NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c                          NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a                          NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b                          NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60                          NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1                          NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1                          NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3                          NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9                          NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc                          NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f                          NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695                          NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1                          NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74                          NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54                          NaN
# a1969a60-46db-4266-923f-b8ee86f9919b                          NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6                          NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129                          NaN
# 649cb11c-488b-42c8-b03c-998c88748415                          NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc                          NaN
# 9de54125-8f04-4707-bedb-03654376cdc0                          NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9                          NaN
# 25a599c1-b26c-40d0-8574-234b2647e707                          NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb                          NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382                          NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c                          NaN
# fbab9669-36ea-48e4-9143-0f5175837976                          NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400                          NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be                          NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604                          NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661                          NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f                          NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8                          NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549                          NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4                          NaN
#
#                                      player_off_permanent  \
# id
# 7b02c827-3580-4149-9912-216ce2bd544f                  NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee                  NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea                  NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7                  NaN
# e472e061-bb70-413a-94e3-1dc1378437b6                  NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27                  NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db                  NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646                  NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20                  NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f                  NaN
# a22c750f-c396-4218-9973-2fdc3a104169                  NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc                  NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624                  NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f                  NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc                  NaN
# bdce1e25-2811-47c7-ac12-4f1919235204                  NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8                  NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700                  NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c                  NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a                  NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b                  NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60                  NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1                  NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1                  NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3                  NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9                  NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc                  NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f                  NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695                  NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1                  NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74                  NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54                  NaN
# a1969a60-46db-4266-923f-b8ee86f9919b                  NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6                  NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129                  NaN
# 649cb11c-488b-42c8-b03c-998c88748415                  NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc                  NaN
# 9de54125-8f04-4707-bedb-03654376cdc0                  NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9                  NaN
# 25a599c1-b26c-40d0-8574-234b2647e707                  NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb                  NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382                  NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c                  NaN
# fbab9669-36ea-48e4-9143-0f5175837976                  NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400                  NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be                  NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604                  NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661                  NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f                  NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8                  NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549                  NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4                  NaN
#
#                                       half_end_early_video_end
# id
# 7b02c827-3580-4149-9912-216ce2bd544f                       NaN
# ad6595c0-e69a-4428-a902-f0ad4139e6ee                       NaN
# f38c74de-91ba-44b1-b95b-fc7e421536ea                       NaN
# 0ca38903-2d66-4306-80db-ce106bc445b7                       NaN
# e472e061-bb70-413a-94e3-1dc1378437b6                       NaN
# c3d6d5b1-b68d-4d8c-87b2-75a9d7e44f27                       NaN
# 29a52984-b52d-4cd7-93f4-0f6d332997db                       NaN
# b86b941b-c27d-4e90-8b69-ee77dffa1646                       NaN
# ddf62112-8330-4164-9b7e-ab34f2f9fa20                       NaN
# d4705b10-9d1a-4ab1-8b79-52d63507923f                       NaN
# a22c750f-c396-4218-9973-2fdc3a104169                       NaN
# fc9ff0d8-8e7d-4f90-8bac-e90cb089b9fc                       NaN
# 8bbfe3f7-2e14-4af7-ad0c-92c786276624                       NaN
# 9e13945c-7e87-42b3-899a-2d19cd039a5f                       NaN
# ba112504-ee72-48ca-ab62-c84f8b4c73fc                       NaN
# bdce1e25-2811-47c7-ac12-4f1919235204                       NaN
# e5af85bf-bee4-4c27-95fa-8c403a8639a8                       NaN
# 75aa4fa2-c6ab-4a2f-bcb8-3025b7397700                       NaN
# 7f8ffcb0-8e3a-455e-8782-a0c19fa4115c                       NaN
# 0cd2f622-8de5-40b3-89c3-258e2a09101a                       NaN
# 055fe6ef-c3b0-4061-88c9-d2a77c87b27b                       NaN
# 4fc0bf2c-6477-4c96-855e-5a0e6d38ea60                       NaN
# c65948b2-62e6-4aad-83f0-58720b99c6f1                       NaN
# 47f6ed32-5527-4d40-972a-5c93b4efeed1                       NaN
# c09c6e64-612b-4ba2-931e-5cde922a24b3                       NaN
# 5656d749-a0c6-4469-bdea-a07ab0919ba9                       NaN
# 5f1f5de5-115f-484d-95c4-19fba32feefc                       NaN
# 30096480-4544-4ef5-a7e3-ac42e2298f5f                       NaN
# d79f4fa7-ca22-4a43-873a-f9d8a0ff7695                       NaN
# bd5ebd93-b60e-4eed-9854-006efaa841d1                       NaN
# e4c7ed88-c603-4d77-84b7-1f0c3ebb7b74                       NaN
# ad41f580-4dc5-4214-895a-ea11a2675e54                       NaN
# a1969a60-46db-4266-923f-b8ee86f9919b                       NaN
# 9350c4f9-1af5-4e19-882a-1728b4a5eeb6                       NaN
# 59b693ed-2d6d-4811-96e3-ba421c414129                       NaN
# 649cb11c-488b-42c8-b03c-998c88748415                       NaN
# eb628fbd-7857-4597-826b-ccb9b52a78cc                       NaN
# 9de54125-8f04-4707-bedb-03654376cdc0                       NaN
# 2cbf0a45-3455-422e-8f7f-9d8db932aef9                       NaN
# 25a599c1-b26c-40d0-8574-234b2647e707                       NaN
# 79503977-6e91-4b5b-9460-d1f0faa6bccb                       NaN
# f7c7d3b5-303d-49f2-8ec6-6d7c59e02382                       NaN
# ed4e4cf4-a3a8-4482-9032-df67e468450c                       NaN
# fbab9669-36ea-48e4-9143-0f5175837976                       NaN
# 7c05e3bf-ce89-46a0-9eb0-d66e2c9d6400                       NaN
# 5cfcb44f-4529-47c2-9228-f8f3c98791be                       NaN
# 6d8b260c-f12a-4328-bff1-6a2cafb88604                       NaN
# 07bf2ae2-7de1-4c63-938a-8ca0792de661                       NaN
# 85cee35b-08af-4e6e-958a-74cbf2f4562f                       NaN
# 3da44fc7-6bac-4aaf-9848-22abab0865f8                       NaN
# ee4ac7bb-2cd9-401f-80a1-53d58327a549                       NaN
# 09a06b42-8ea2-49fa-a3c1-096e914c92c4                       NaN
#
# [52 rows x 95 columns]

# %%
no_games = len(barcelona_goals_away)

#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(barcelona_goals_away.x, barcelona_goals_away.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Goals by ' + team + " per game for away games", fontsize = 30)
plt.show()

# %%
no_games = len(barcelona_goals_home)

#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(barcelona_goals_home.x, barcelona_goals_home.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Goals by ' + team + " per game for home games", fontsize = 30)
plt.show()

# %%
df_laliga_events.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'counterpress', 'pass_switch',
#        'technique_id', 'technique_name', 'pass_cross', 'off_camera', 'out',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'shot_statsbomb_xg',
#        'end_z', 'shot_key_pass_id', 'goalkeeper_position_id',
#        'goalkeeper_position_name', 'aerial_won', 'foul_committed_advantage',
#        'foul_won_advantage', 'shot_one_on_one', 'dribble_nutmeg',
#        'dribble_overrun', 'shot_first_time', 'pass_deflected',
#        'pass_goal_assist', 'ball_recovery_recovery_failure',
#        'foul_won_defensive', 'substitution_replacement_id',
#        'substitution_replacement_name', 'foul_committed_card_id',
#        'foul_committed_card_name', 'pass_no_touch', 'block_deflection',
#        'pass_cut_back', 'block_offensive', 'shot_deflected', 'id_related',
#        'index_related', 'type_name_related', 'teammate', 'event_freeze_id',
#        'jersey_number', 'event_tactics_id', 'injury_stoppage_in_chain',
#        'foul_committed_offensive', 'pass_miscommunication',
#        'ball_recovery_offensive', 'bad_behaviour_card_id',
#        'bad_behaviour_card_name', 'foul_committed_penalty', 'foul_won_penalty',
#        'shot_open_goal', 'block_save_block', 'dribble_no_touch',
#        'shot_redirect', 'shot_follows_dribble', 'half_start_late_video_start',
#        'player_off_permanent', 'half_end_early_video_end'],
#       dtype='object')

# %%
df_laliga_events['sub_type_name'].unique()
# Out:
# array([nan, 'Kick Off', 'Interception', 'Tackle', 'Throw-in', 'Recovery',
#        'Goal Kick', 'Corner', 'Open Play', 'Shot Faced', 'Aerial Lost',
#        'Shot Saved', 'Free Kick', 'Goal Conceded', 'Punch', 'Handball',
#        'Keeper Sweeper', 'Collected', 'Dangerous Play', 'Penalty',
#        'Penalty Conceded', 'Save', 'Shot Saved Off Target',
#        'Shot Saved to Post', 'Penalty Saved', 'Foul Out', 'Smother',
#        'Dive', '6 Seconds', 'Backpass Pick', 'Saved to Post'],
#       dtype=object)

# %%
df_laliga_events['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Ball Receipt', 'Pass', 'Carry',
#        'Pressure', 'Interception', 'Dispossessed', 'Duel', 'Miscontrol',
#        'Ball Recovery', 'Dribbled Past', 'Dribble', 'Clearance', 'Shot',
#        'Goal Keeper', 'Block', 'Foul Committed', 'Foul Won', 'Shield',
#        'Half End', 'Substitution', 'Injury Stoppage', 'Referee Ball-Drop',
#        'Tactical Shift', nan, 'Own Goal Against', 'Own Goal For',
#        'Bad Behaviour', '50/50', 'Offside', 'Error', 'Player Off',
#        'Player On', 'Camera off', 'Camera On'], dtype=object)

# %% [markdown]
# #### Defensive actions

# %% [markdown]
# #### 1. Type_name - Pressure

# %%
df_pressure_home = df_season1_home_events[df_season1_home_events['type_name'] == "Pressure"]

# %%
df_pressure_home = df_pressure_home[df_pressure_home['team_name'] == team]

# %% [markdown]
# ### Here we are trying to get see how successful is pressure applying and where do barcelona do it more often. Moreover, I want to see which player has the highest successful pressure in each third of the pitch.
#
# #### But how do we know if it is a successful pressure? By taking the ball back but within 5 seconds?

# %% [markdown]
# ##### 1. Pressure heatmap on home games

# %%
no_games = len(df_pressure_home)

#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(df_pressure_home.x, df_pressure_home.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Pressure heatmap of ' + team + " per game for home games", fontsize = 30)
plt.show()

# %% [markdown]
# ##### 2. Pressure heat map on away games

# %%
df_pressure_away = df_season1_away_events[df_season1_away_events['type_name'] == "Pressure"]
df_pressure_away = df_pressure_away[df_pressure_away['team_name'] == team]

# %%
no_games = len(df_pressure_away)

#plot vertical pitch
pitch = Pitch(line_zorder=2, line_color='black')
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
#get the 2D histogram
bin_statistic = pitch.bin_statistic(df_pressure_away.x, df_pressure_away.y, statistic='count', bins=(12, 12), normalize=False)
#normalize by number of games
bin_statistic["statistic"] = bin_statistic["statistic"]/no_games
#make a heatmap
pcm  = pitch.heatmap(bin_statistic, cmap='Reds', edgecolor='grey', ax=ax['pitch'])
#legend to our plot
ax_cbar = fig.add_axes((1, 0.093, 0.03, 0.786))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Pressure heatmap of ' + team + " per game for away games", fontsize = 30)
plt.show()

# %% [markdown]
# #### Successfull pressure????

# %%
df_9880 = df_pressure_home[df_pressure_home['match_id']== 9880]

# %%
from datetime import datetime, timedelta


df_pressure_BA_home_events = pd.DataFrame()
df_pressure_home['timestamp'] = pd.to_datetime(df_pressure_home['timestamp'].astype(str))


# Function to fetch matches based on 'competition_id' and 'season_id' values
def fetch_events_fromMatchID(row):
    current_timestamp = row['timestamp']
    target_time = datetime.strptime(current_timestamp, "%H:%M:%S.%f").time()
    
    # Calculate the time range
    time_delta = timedelta(seconds=5)
    start_time = datetime.combine(datetime.min.date(), target_time) - time_delta
    end_time = datetime.combine(datetime.min.date(), target_time) + time_delta


    # Calculate the time range
    start_time = current_timestamp - pd.Timedelta(seconds=5)
    end_time = current_timestamp + pd.Timedelta(seconds=5)
    # Your logic or function based on 'competition_id' and 'season_id' values
    filtered_df = df_season1_home_events[(df_season1_home_events['timestamp'].dt.time >= start_time.time()) & (df_season1_home_events['timestamp'].dt.time <= end_time.time())]
    return filtered_df

# Iterate through the rows and fetch matches
for index, row in df_pressure_home.iterrows():
    events = fetch_events_fromMatchID(row)
    # Append the matches to df_championsLeague_matches
    df_pressure_BA_home_events = df_pressure_BA_home_events.append(events, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [300], in <cell line: 27>()
#      26 # Iterate through the rows and fetch matches
#      27 for index, row in df_pressure_home.iterrows():
# ---> 28     events = fetch_events_fromMatchID(row)
#      29     # Append the matches to df_championsLeague_matches
#      30     df_pressure_BA_home_events = df_pressure_BA_home_events.append(events, ignore_index=True)
#
# Input In [300], in fetch_events_fromMatchID(row)
#       9 def fetch_events_fromMatchID(row):
#      10     current_timestamp = row['timestamp']
# ---> 11     target_time = datetime.strptime(current_timestamp, "%H:%M:%S.%f").time()
#      13     # Calculate the time range
#      14     time_delta = timedelta(seconds=5)
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
df_pressure_home[['x','y','timestamp']]
# Out:
#            x     y               timestamp
# 74      77.2   5.1 2023-06-29 00:01:39.006
# 78      93.7   5.9 2023-06-29 00:01:41.466
# 86      53.9  18.7 2023-06-29 00:01:58.534
# 88      36.6  50.9 2023-06-29 00:02:00.403
# 102     56.1  36.5 2023-06-29 00:02:06.048
# ...      ...   ...                     ...
# 212607  34.4  30.7 2023-06-29 00:42:09.922
# 212668  41.4  37.7 2023-06-29 00:45:20.185
# 212713  90.8  10.6 2023-06-29 00:46:10.702
# 212728  55.8  14.1 2023-06-29 00:46:19.988
# 212737  53.7  21.6 2023-06-29 00:46:21.374
#
# [2347 rows x 3 columns]

# %%
type(df_9880['timestamp'])
# Out:
# pandas.core.series.Series

# %%
df_9880.dtypes
# Out:
# id                              object
# index                          float64
# period                         float64
# timestamp                       object
# minute                         float64
#                                 ...
# shot_redirect                   object
# shot_follows_dribble            object
# half_start_late_video_start     object
# player_off_permanent            object
# half_end_early_video_end        object
# Length: 96, dtype: object

# %%
df_pressure_home.dtypes
# Out:
# id                                     object
# index                                 float64
# period                                float64
# timestamp                      datetime64[ns]
# minute                                float64
#                                     ...
# shot_redirect                          object
# shot_follows_dribble                   object
# half_start_late_video_start            object
# player_off_permanent                   object
# half_end_early_video_end               object
# Length: 96, dtype: object
